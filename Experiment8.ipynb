# %% [markdown]
# <a href="https://colab.research.google.com/github/Avihardik123/Avinash192312463-ITA0604-Machine-Learning/blob/main/Experiment8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

X=np.array([[1],[2],[3],[4],[5],[6]])
Y=np.array([2,4,5,4,5,7])

model=LinearRegression()

model.fit(X,Y)

pred=model.predict(X)

print("Slope =",model.coef_)
print("Intercept =",model.intercept_)

plt.scatter(X,Y)
plt.plot(X,pred,color="red")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()
# Out:
# Slope = [0.77142857]
# Intercept = 1.7999999999999998
